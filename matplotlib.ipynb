# %% [markdown]
# <a href="https://colab.research.google.com/github/da-matsumoto/machine/blob/practice/matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import matplotlib.style

matplotlib.style.use('seaborn')

x = [1, 2, 3]
y = [2, 1, 3]
x2 = [1, 2, 3]
y2 = [-2, -4, -6]

fig, ax = plt.subplots()
ax.plot(x, y, label='sample legend')
ax.set_title('Subplot1 title')
ax.set_title('subplot2 title')
fig.suptitle('Graph title')
ax.set_xlabel('X label')
ax.set_ylabel('Y label')
ax.legend(loc='lower right')
plt.show()
